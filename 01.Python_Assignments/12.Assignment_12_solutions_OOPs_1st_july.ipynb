# %% [markdown]
# # Assignment by:

# %% [markdown]
# ![ineuron-logo.png](attachment:ineuron-logo.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# ### Q1. What  is  the  primary  goal  of  Object-Oriented  Programming  (OOP)?
# **Answer:**

# %% [markdown]
# The primary goal of Object-Oriented Programming is to create code that is robust,adaptable, reusable and maintanable.
# OOP achieves these goals  by allowing programmers to create objects that represents real-world entities.
#
# By using OOP , programmers can design and create objects from classes, which serve as blueprints, defining the properties (attributes) and behaviors (methods) of the objects.
#
# The goals are as follows:
#
# * **Robustness** : OOP can help to improve the robustness of the code that means improves the strength of the software,indicating its ability to handle a wide range of scenarious,inputs and errors without breaking or producing incorrect results.
#
# * **Adaptability**: OOP can help to improve the adaptability of code by making it easier to add new features or change existing features.
#
# * **Reusability and Maintenance**: OOP can help to improve the reusability of code by making it easier to reuse existing objects and code.And as it is modular code this is easy to maintain and make changes if needed.
#
# Overall, OOP can be a very powerful tool for creating well-organized, efficient, and maintainable code.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# ### Q2. What  is  an  object  in  Python?
# **Answer:**

# %% [markdown]
# * An Object in Python is a specific instance of a class.
# * Object represents a unique entity that has its own set of data and can perform actions as defined in its class.Data or properties is called attributes  and actions or behaviours is called as methods.
# * An object is created by instantating a class which means creating a new instance of that class.
#
# **Example: Creating a class Car and creating objects of it,also calling attributes and methods of it.**

# %%
class Car:
    def __init__(self, color, model,brand):  #color,model and brand are attributes 
        self.color = color     
        self.model = model
        self.brand=brand
        
    def start(self):           #start is the method : Responsible for action or behaviour.
        print(f"The Car of brand:{self.brand} , model : {self.model} and of color: {self.color} is Starting!!!")

# %%
car1 = Car("Red", "Nexon","TATA")   # Creating an instance of the class Car,therefore this 'car1' is an object of class Car.

# %%
car1.brand   #Calling the attributes of the class whose car1 is the object.
             #Calling attribute:brand
# Out:
# 'TATA'

# %%
car1.model   #Calling attribute : model
# Out:
# 'Nexon'

# %%
car1.color   #Calling attribute:color
# Out:
# 'Red'

# %%
car1.start()  #Calling the method of the class Car which got customized as we have created an object which specific inputs.
# Out:
# The Car of brand:TATA , model : Nexon and of color: Red is Starting!!!

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ### Q3. What  is  a  class  in  Python?
# **Answer:**

# %% [markdown]
# * A class is a blueprint for creating objects (also known as instances).
# * A class have set of attributes (which are basically properties or variables) and methods ( actions/behaviours).
# * To create a Class we have to use keyword 'class'.

# %%
class Car:     #Creating a class of name Car.
    pass

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------
# ### Q4. What  are  attributes  and  methods  in  a  class?
# **Answer:**

# %% [markdown]
# * Attributes are the data or variables or properties defined inside the class.
# * Methods are the actions or functions or behaviours defined inside the class.

# %%
class Car:
    def __init__(self, color, model,brand):  #color,model and brand are attributes 
        self.color = color     
        self.model = model
        self.brand=brand
        
    def start(self):           #start is the method : Responsible for action or behaviour.
        print(f"The Car of brand:{self.brand} , model : {self.model} and of color: {self.color} is Starting!!!")

# %%
car2=Car("Black","EV","BMW")

# %%
car2.brand   # Here from the class Car we are able to call its specific attributes using the object of the class.
# Out:
# 'BMW'

# %%
car2.start() #Here from the class Car we are able to call its specific method ,using the object of the class .
# Out:
# The Car of brand:BMW , model : EV and of color: Black is Starting!!!

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------
# ### Q5. What  is  the  difference  between  class  variables  and  instance  variables  in  Python?
# **Answer:**

# %% [markdown]
# Class Variables:
# * Class variables are defined within the class but outside of any class methods.
# * Class variables are useful for storing the data which we want it to be default or constant value for all the object/instance.
# * We can access the class variable by using class name followed by the variable name.
# * Class variables are initialised either inside the class or outside the class definiton.

# %% [markdown]
# Instance Variables:
# * Instance Variables are defined within the class methods,typically the constructor
#
#         __init__
# * Instance variables are useful for storing the data that are unqiue to each instance of the class.
# * We can access the instance variable by using instance name followed by the variable name.
# * Instance variables are typically initialized in the constructor of the class.
# * If we make change to instance variable, then this won't affect all the instance or object.Changes only happen in specific instance variable.

# %% [markdown]
# **Example**

# %%
class Circle:
    
    pi = 3.14159  #Class variable: pi is a class variable defined within the class,outside the methods.
    

    def __init__(self, radius):
        self.radius = radius  #Instance Variable: radius is an instance variable initialized in the constructor.

    def calculate_area(self):
        
        # Accessing the class variable inside a method 
        
        return Circle.pi * self.radius ** 2   # Circle.pi : Accessing class variable using class name

# %%
#Accessing the class variable.
Circle.pi
# Out:
# 3.14159

# %%
# Creating instances of Circle class
circle1 = Circle(5)   #passing radius as : 5
circle2 = Circle(3)   #passing radius as : 3

# %%
#Accessing the instance variable.
print(f'The radius of circle1 is:{circle1.radius}')
print(f'We have value of pi in cirlce1: {circle1.pi}\n') #We can also access the class variable aslo using object.

print(f'The radius of circle2 is:{circle2.radius}')
print(f'We have value of pi in cirlce2: {circle2.pi}') #We can also access the class variable aslo using object.
# Out:
# The radius of circle1 is:5
# We have value of pi in cirlce1: 3.14159
#
# The radius of circle2 is:3
# We have value of pi in cirlce2: 3.14159

# %%
#Calling the method and accessing instance variables.

print(f"The radius of circle1 is {circle1.radius} and therefore Area of Circle is:",circle1.calculate_area())
print(f"The radius of circle2 is {circle2.radius} and therefore Area of Circle is:",circle2.calculate_area())
# Out:
# The radius of circle1 is 5 and therefore Area of Circle is: 78.53975
# The radius of circle2 is 3 and therefore Area of Circle is: 28.27431

# %%
#Modifying the class variable.
print("Before modification of class variable:",Circle.pi)


Circle.pi= 22/7

print("After modification of class variable:",Circle.pi)
# Out:
# Before modification of class variable: 3.14159
# After modification of class variable: 3.142857142857143

# %%
#Lets again reassign the value 3.14 to pi so that we can find area with pi value 3.14


Circle.pi= 3.14
print("Reassign pi class variable:",Circle.pi)
# Out:
# Reassign pi class variable: 3.14

# %%
#Modifying the instance variable.
print("Before modification of instance variable:",circle1.radius)
print(f"The radius of circle1 is {circle1.radius} and therefore Area of Circle is:",circle1.calculate_area(),"\n")

circle1.radius= 8

print("After modification of class variable:",circle1.radius)
print(f"The radius of circle1 is {circle1.radius} and therefore Area of Circle is:",circle1.calculate_area())
# Out:
# Before modification of instance variable: 5
# The radius of circle1 is 5 and therefore Area of Circle is: 78.5
#
# After modification of class variable: 8
# The radius of circle1 is 8 and therefore Area of Circle is: 200.96

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# ### Q 6. What  is  the  purpose  of  the  self  parameter  in  Python  class  methods?
# **Answer:**

# %% [markdown]
# **self : self is referring to the current object.**

# %% [markdown]
# * The self parameter is used to link the methods of the class to the instance of the class, which enable the method to work with the data provided to the object or instance.
# * In python it is convention to use self as the first parameter in instance methods , however we can choose any valid name inplace of using self.
# * The self is automatically passed when a method is called on an instance.So we don't need to explicitly provide a value for it when invoking the method.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# ### Q7.For  a  library  management  system,  you  have  to  design  the  "Book"  class  with  OOP principles  in  mind.  The  “Book”  class  will  have  following  attributes:
#     a.      title:  Represents  the  title  of  the  book.
#     b.      author:  Represents  the  author(s)  of  the  book.
#     c.      isbn:  Represents  the  ISBN  (International  Standard  Book  Number)  of  the  book.
#     d.      publication_year:  Represents  the  year  of  publication  of  the  book.
#     e.      available_copies:  Represents  the  number  of  copies  available  for  checkout.
#
# ### The  class  will  also  include  the  following  methods:
#     a.      check_out(self):  Decrements  the  available  copies  by  one  if  there  are  copies available  for  checkout.
#     b.      return_book(self):  Increments  the  available  copies  by  one  when  a  book  is returned.
#     c.      display_book_info(self):  Displays  the  information  about  the  book,  including  its attributes  and
#     the number  of  available  copies.
#
# **Answer:**

# %%
class Book:
    def __init__(self,title,author,isbn,publication_year,available_copies):
        self.title=title
        self.author=author
        self.isbn=isbn
        self.publication_year=publication_year
        self.available_copies=available_copies

    def check_out(self):
        print("Number of Available copies in the Library :",self.available_copies)
        
        if self.available_copies > 0:
            self.available_copies -= 1  # Decrements  the  available  copies  by  one  if  there  are  copies 
                                        #available  for  checkout.
                
            print(f"\nThe Book {self.title} checked out successfully!!!")
            
        else:
            print(f"\nNo copies of book {self.title} are available for checkout.")
        print(f"\nNow, the number of available copies after check_out  :{self.available_copies}")
        
        
    
    
    def return_book(self):
        print("Number of Available copies in the Library :",self.available_copies)
        self.available_copies += 1  #Increments  the  available  copies  by  one  when  a  book  is returned.
        print(f"\nBook Named {self.title} returned successfully!!!")
        print(f"\nNow,the number of available copies after returning book  :{self.available_copies}")

        
    
    def display_book_info(self):
        print("Book Information:")
        print(f"Title: {self.title}")
        print(f"Author(s): {self.author}")
        print(f"ISBN: {self.isbn}")
        print(f"Publication Year: {self.publication_year}")
        print(f"Available Copies : {self.available_copies}")

# %% [markdown]
# **👩‍💻Creating the first object for class Book.**

# %%
book1= Book("Atomic Habits","James Clear","9780-735211292", 2018,21)

# %%
book1

# %% [markdown]
# **✨ Calling the attributes of the class Book for first object book1**

# %%
book1.title   #Getting the attribute value title from class Book.
# Out:
# 'Atomic Habits'

# %%
book1.author  #Getting the attribute value author from class Book.
# Out:
# 'James Clear'

# %%
book1.isbn    #Getting the attribute value isbn from class Book.
# Out:
# '9780-735211292'

# %%
book1.available_copies  #Getting the attribute value available_copies from class Book.
# Out:
# 21

# %%
book1.publication_year #Getting the attribute value publication_year from class Book.
# Out:
# 2018

# %% [markdown]
# **✨ Calling the methods of the class Book for first object book1**

# %%
book1.display_book_info()  #Initial numbers of available copies were 21 copies.
# Out:
# Book Information:
# Title: Atomic Habits
# Author(s): James Clear
# ISBN: 9780-735211292
# Publication Year: 2018
# Available Copies : 21

# %%
book1.check_out()    #During checkout 1 copy out of the available copies got check out so left must be 20.
# Out:
# Number of Available copies in the Library : 21
#
# The Book Atomic Habits checked out successfully!!!
#
# Now, the number of available copies after check_out  :20

# %%
book1.display_book_info()
# Out:
# Book Information:
# Title: Atomic Habits
# Author(s): James Clear
# ISBN: 9780-735211292
# Publication Year: 2018
# Available Copies : 20

# %%
book1.return_book()  #After return of book the available copies will be before return copies + returned copies = 20+1=21
# Out:
# Number of Available copies in the Library : 20
#
# Book Named Atomic Habits returned successfully!!!
#
# Now,the number of available copies after returning book  :21

# %% [markdown]
# **👩‍💻Creating the second object for class Book.**

# %%
book2=Book("Advanced Mathematical Analysis","S. C. Malik","978-8170089941",2019,13)

# %%
book2

# %% [markdown]
# **✨ Calling the attributes of the class Book for second object book2**

# %%
book2.title   #Getting the attribute value title from class Book.
# Out:
# 'Advanced Mathematical Analysis'

# %%
book2.author  #Getting the attribute value author from class Book.
# Out:
# 'S. C. Malik'

# %%
book2.isbn    #Getting the attribute value isbn from class Book.
# Out:
# '978-8170089941'

# %%
book2.available_copies  #Getting the attribute value available_copies from class Book.
# Out:
# 13

# %%
book2.publication_year #Getting the attribute value publication_year from class Book.
# Out:
# 2019

# %% [markdown]
# **✨ Calling the methods of the class Book for second object book2**

# %%
book2.display_book_info()  #Initial numbers of available copies were 13 copies.
# Out:
# Book Information:
# Title: Advanced Mathematical Analysis
# Author(s): S. C. Malik
# ISBN: 978-8170089941
# Publication Year: 2019
# Available Copies : 13

# %%
book2.check_out()    #During checkout 1 copy out of the available copies got check out so left must be 12.
# Out:
# Number of Available copies in the Library : 13
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :12

# %%
book2.display_book_info()    #Current details.....
# Out:
# Book Information:
# Title: Advanced Mathematical Analysis
# Author(s): S. C. Malik
# ISBN: 978-8170089941
# Publication Year: 2019
# Available Copies : 12

# %%
book2.return_book() #After return of book the available copies will be before return copies + returned copies = 12+1=13
# Out:
# Number of Available copies in the Library : 12
#
# Book Named Advanced Mathematical Analysis returned successfully!!!
#
# Now,the number of available copies after returning book  :13

# %% [markdown]
# ##### 📚Supoose 5 students wants the book2 and they issued them /check out one by one ....

# %%
book2.check_out()   # 1st student ask for 1 book of "Advanced Mathematical Analysis" by "S. C. Malik".
# Out:
# Number of Available copies in the Library : 13
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :12

# %%
book2.check_out()   # 2nd student ask for 1 book of "Advanced Mathematical Analysis" by "S. C. Malik".
# Out:
# Number of Available copies in the Library : 12
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :11

# %%
book2.check_out()   # 3rd student ask for 1 book of "Advanced Mathematical Analysis" by "S. C. Malik".
# Out:
# Number of Available copies in the Library : 11
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :10

# %%
book2.check_out()   # 4th student ask for 1 book of "Advanced Mathematical Analysis" by "S. C. Malik".
# Out:
# Number of Available copies in the Library : 10
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :9

# %%
book2.check_out()   # 5th student ask for 1 book of "Advanced Mathematical Analysis" by "S. C. Malik".
# Out:
# Number of Available copies in the Library : 9
#
# The Book Advanced Mathematical Analysis checked out successfully!!!
#
# Now, the number of available copies after check_out  :8

# %%
book2.display_book_info()
# Out:
# Book Information:
# Title: Advanced Mathematical Analysis
# Author(s): S. C. Malik
# ISBN: 978-8170089941
# Publication Year: 2019
# Available Copies : 8

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------
# ### Q8. For  a  ticket  booking  system,  you  have  to    design  the  "Ticket"  class  with  OOP principles  in  mind.  The  “Ticket”  class  should  have  the  following  attributes:
#     a.      ticket_id:  Represents  the  unique  identifier  for  the  ticket.
#     b.      event_name:  Represents  the  name  of  the  event.
#     c.      event_date:  Represents  the  date  of  the  event.
#     d.      venue:  Represents  the  venue  of  the  event.
#     e.      seat_number:  Represents  the  seat  number  associated  with  the  ticket.
#     f.        price:  Represents  the  price  of  the  ticket.
#     g.      is_reserved:  Represents  the  reservation  status  of  the  ticket.
# ### The  class  also  includes  the  following  methods:
#     a.      reserve_ticket(self):  Marks  the  ticket  as  reserved  if  it  is  not  already  reserved.
#     b.      cancel_reservation(self):  Cancels  the  reservation  of  the  ticket  if  it  is  already reserved.
#     c.      display_ticket_info(self):  Displays  the  information  about  the  ticket,  including  its attributes  and  reservation  status.
#
# **Answer:**

# %%
class Ticket:
    def __init__(self,ticket_id,event_name,event_date,venue,seat_number,price,is_reserved):
        self.ticket_id=ticket_id
        self.event_name=event_name
        self.event_date=event_date
        self.venue=venue
        self.seat_number=seat_number
        self.price=price
        self.is_reserved=is_reserved
        
        
        
    def reserve_ticket(self):
        
        
        if self.is_reserved==False:
            print("Sorry!!! Your seat is not reserved.")
            mark=input("Enter 'R' or 'r' to reserved the seat.")
            
            if mark=='R' or mark=='r':
                self.is_reserved=True  #Marking  the  ticket  as  reserved  if  it  is  not  already  reserved.
                
                print(f"Ticket id: {self.ticket_id} with seat_no: {self.seat_number} is Reserved Successfully!!!")
            else:
                print("Please enter the correct input as 'R' or 'r'")
                
        else:
            print(f"Ticket id: {self.ticket_id} with seat_no: {self.seat_number} is already Reserved.")
    
    
    def cancel_reservation(self):
        if self.is_reserved==True:
            mark=input("Enter 'C' or 'c' to Cancel the Ticket!!!")
            
            if mark=='C' or mark=='c':
                self.is_reserved=False  #Cancels  the  reservation  of  the  ticket  if  it  is  already reserved.
                
                print(f"Ticket id: {self.ticket_id} with seat_no: {self.seat_number} is Cancelled Successfully !!!")
            else:
                 print("Please enter the correct input as 'C' or 'c'")
                
               
                
        else:
             print(f"You Have no reservation to cancel.Have a good day ahead.")
        
    
    
    
    def display_ticket_info(self):
        print("Ticket ID:", self.ticket_id)
        print("Event Name:", self.event_name)
        print("Event Date:", self.event_date)
        print("Venue:", self.venue)
        print("Seat Number:", self.seat_number)
        print("Price:", self.price)
        
        if self.is_reserved==True:
            print(f"Ticket id: {self.ticket_id} with seat_no: {self.seat_number} is Reserved")
        else:
            print(f"Ticket is not Reserved")

# %%
ticket1 = Ticket(100012, "Concert", "2023-07-15", "ABC ground Alkapuri", "A12", 1500,False)

# %%
ticket1.ticket_id
# Out:
# 100012

# %%
ticket1.event_name
# Out:
# 'Concert'

# %%
ticket1.event_date
# Out:
# '2023-07-15'

# %%
ticket1.seat_number
# Out:
# 'A12'

# %%
ticket1.venue
# Out:
# 'ABC ground Alkapuri'

# %%
ticket1.price
# Out:
# 1500

# %%
ticket1.is_reserved
# Out:
# False

# %%
ticket1.reserve_ticket()
# Out:
# Sorry!!! Your seat is not reserved.
# Enter 'R' or 'r' to reserved the seat.r
# Ticket id: 100012 with seat_no: A12 is Reserved Successfully!!!

# %%
ticket1.reserve_ticket()  #Lets checking is it showing reserved now or not? Yes it is showing reserved ticket now.
# Out:
# Ticket id: 100012 with seat_no: A12 is already Reserved.

# %%
ticket1.display_ticket_info()
# Out:
# Ticket ID: 100012
# Event Name: Concert
# Event Date: 2023-07-15
# Venue: ABC ground Alkapuri
# Seat Number: A12
# Price: 1500
# Ticket id: 100012 with seat_no: A12 is Reserved

# %%
ticket1.cancel_reservation()
# Out:
# Enter 'C' or 'c' to Cancel the Ticket!!!c
# Ticket id: 100012 with seat_no: A12 is Cancelled Successfully !!!

# %%
ticket1.display_ticket_info()
# Out:
# Ticket ID: 100012
# Event Name: Concert
# Event Date: 2023-07-15
# Venue: ABC ground Alkapuri
# Seat Number: A12
# Price: 1500
# Ticket is not Reserved

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------
# ### Q9. You  are  creating  a  shopping  cart  for  an  e-commerce  website.  Using  OOP  to  model the  "ShoppingCart"  functionality  the  class  should  contain  following  attributes  and methods:
#     a.      items:  Represents  the  list  of  items  in  the  shopping  cart.
#
# ### The  class  also  includes  the  following    methods:
#
#     a.      add_item(self,  item):  Adds  an  item  to  the  shopping  cart  by  appending  it  to  the list  of  items.
#     b.      remove_item(self,  item):  Removes  an  item  from  the  shopping  cart  if  it  exists  in the  list.
#     c.      view_cart(self):  Displays  the  items  currently  present  in  the  shopping  cart.
#     d.      clear_cart(self):  Clears  all  items  from  the  shopping  cart  by  reassigning  an empty  list  to  the  items  attribute.
#
# **Answer:**

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []
        
    def add_item(self, *items):
        for item in items:
            self.items.append(item)
            print(f"Item '{item}' added to the shopping cart successfully!!!.")
    
    def remove_item(self, *items):
        for item in items:
            if item in self.items:
                self.items.remove(item)
                print(f"The item '{item}' got removed from the shopping cart successfully!")
            else:
                print(f"Item '{item}' is not found in the shopping cart.")
    
    def view_cart(self):
        if len(self.items) > 0:
            for i in range(len(self.items)):
                print(f"{i+1} ---> {self.items[i]}")
        else:
            print("The shopping cart is empty.")
    
    def clear_cart(self):
        self.items = []
        print("The shopping cart is empty.")

# %%
sc1=ShoppingCart()

# %%
sc1.items
# Out:
# []

# %%
sc1.add_item("Shirt", "Shoes", "Hat","Jeans","Sneakers","Books","Speaker")
# Out:
# Item 'Shirt' added to the shopping cart successfully!!!.
# Item 'Shoes' added to the shopping cart successfully!!!.
# Item 'Hat' added to the shopping cart successfully!!!.
# Item 'Jeans' added to the shopping cart successfully!!!.
# Item 'Sneakers' added to the shopping cart successfully!!!.
# Item 'Books' added to the shopping cart successfully!!!.
# Item 'Speaker' added to the shopping cart successfully!!!.

# %%
sc1.view_cart()
# Out:
# 1 ---> Shirt
# 2 ---> Shoes
# 3 ---> Hat
# 4 ---> Jeans
# 5 ---> Sneakers
# 6 ---> Books
# 7 ---> Speaker

# %%
sc1.remove_item("Shoes","Jeans","Mouse")
# Out:
# The item 'Shoes' got removed from the shopping cart successfully!
# The item 'Jeans' got removed from the shopping cart successfully!
# Item 'Mouse' is not found in the shopping cart.

# %%
sc1.view_cart()
# Out:
# 1 ---> Shirt
# 2 ---> Hat
# 3 ---> Sneakers
# 4 ---> Books
# 5 ---> Speaker

# %%
sc1.clear_cart()
# Out:
# The shopping cart is empty.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------
# ### Q10. Imagine  a  school  management  system.  You  have  to    design  the  "Student"  class  using OOP  concepts.The  “Student”  class  has  the  following  attributes:
#     a.      name:  Represents  the  name  of  the  student.
#     b.      age:  Represents  the  age  of  the  student.
#     c.      grade:  Represents  the  grade  or  class  of  the  student.
#     d.      student_id:  Represents  the  unique  identifier  for  the  student.
#     e.      attendance:  Represents  the  attendance  record  of  the  student.
#
# The  class  should  also  include  the  following  methods:
#
#     a.      update_attendance(self,  date,  status):  Updates  the  attendance  record  of  the student  for  a  given  date  with  the  provided  status  (e.g.,  present  or  absent).
#     b.      get_attendance(self):  Returns  the  attendance  record  of  the  student.
#     c.      get_average_attendance(self):  Calculates  and  returns  the  average attendance  percentage  of  the  student  based  on  their  attendance  record.
#
# **Answer:**

# %%
class Student:
    def __init__(self, name, age, grade, student_id):
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = {}  # Initializing an empty dict.

    def get_attendance(self):    #This simply returns the dict of attendance
        return self.attendance

    def update_attendance(self, date, status):
        
        
        #With this update, each time we call the update_attendance method, a new key-value
        #pair will be added to the attendance dictionary, with the date as the key and the status as the value.
    
    
        self.attendance[date] = status  #we are updating the attendance dictionary attribute of 
                                        #the Student class with a new entry as date and status.

    def get_average_attendance(self):
        total_days = len(self.attendance)
        present_days = 0

        for status in self.attendance.values():
            if status == 'present':
                present_days += 1

        if total_days > 0:
            average_attendance = (present_days / total_days) * 100 
            average_attendance = round(average_attendance, 2)    #Rounding of to 2 decimals

        else:
            average_attendance = 0

        return average_attendance

# %%
student1 = Student("Rashmi", 16, "10th", "2015002")

# %%
#Calling update attendance
student1.update_attendance("2023-07-10", "present")
student1.update_attendance("2023-07-11", "absent")
student1.update_attendance("2023-07-12", "present")
student1.update_attendance("2023-07-13", "present")
student1.update_attendance("2023-07-14", "absent")
student1.update_attendance("2023-07-15", "present")

# %%
# Calling get attendance record
student1.get_attendance()
# Out:
# {'2023-07-10': 'present',
#  '2023-07-11': 'absent',
#  '2023-07-12': 'present',
#  '2023-07-13': 'present',
#  '2023-07-14': 'absent',
#  '2023-07-15': 'present'}

# %%
# Calling get average attendance
student1.get_average_attendance()
# Out:
# 66.67

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ![5.gif](attachment:5.gif)
